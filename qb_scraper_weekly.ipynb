# %%
import pandas as pd
import requests
import os
import re

# %%
if not os.path.exists('./nfl_data/weekly/cbs_weekly'):
    os.mkdir('./nfl_data/weekly/cbs_weekly')

# %% [markdown]
# #### Scrapes CBS Weekly for all positions & all weeks
# Saves files to `cbs_weekly` directory

# %%
positions = ['QB', 'WR', 'RB', 'TE', 'K']
weeks = [19, 20, 21, 23] # 22 was pro bowl

file_list = []

for position in positions:
    for week in weeks:
        url = f'https://www.cbssports.com/nfl/stats/leaders/live/{position}/{week}/'
        print(url)
        res = requests.get(url)
        print(res)
        output = open(f'./nfl_data/weekly/cbs_weekly/week-{week}_{position}.xls', 'wb')
        output.write(res.content)
        file_list.append(f'./nfl_data/weekly/cbs_weekly/week-{week}_{position}.xls')
        output.close()
        data = pd.read_html(f'./nfl_data/weekly/cbs_weekly/week-{week}_{position}.xls')
        df = data[0]
        # df = df.droplevel(0, axis=1)
        print((position, week), df.shape)
# Out:
# https://www.cbssports.com/nfl/stats/leaders/live/QB/19/
# <Response [200]>
# ('QB', 19) (13, 11)
# https://www.cbssports.com/nfl/stats/leaders/live/QB/20/
# <Response [200]>
# ('QB', 20) (8, 11)
# https://www.cbssports.com/nfl/stats/leaders/live/QB/21/
# <Response [200]>
# ('QB', 21) (3, 11)
# https://www.cbssports.com/nfl/stats/leaders/live/QB/23/
# <Response [200]>
# ('QB', 23) (2, 11)
# https://www.cbssports.com/nfl/stats/leaders/live/WR/19/
# <Response [200]>
# ('WR', 19) (56, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/WR/20/
# <Response [200]>
# ('WR', 20) (39, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/WR/21/
# <Response [200]>
# ('WR', 21) (14, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/WR/23/
# <Response [200]>
# ('WR', 23) (10, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/RB/19/
# <Response [200]>
# ('RB', 19) (35, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/RB/20/
# <Response [200]>
# ('RB', 20) (19, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/RB/21/
# <Response [200]>
# ('RB', 21) (10, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/RB/23/
# <Response [200]>
# ('RB', 23) (7, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/TE/19/
# <Response [200]>
# ('TE', 19) (22, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/TE/20/
# <Response [200]>
# ('TE', 20) (16, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/TE/21/
# <Response [200]>
# ('TE', 21) (4, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/TE/23/
# <Response [200]>
# ('TE', 23) (2, 10)
# https://www.cbssports.com/nfl/stats/leaders/live/K/19/
# <Response [200]>
# ('K', 19) (12, 6)
# https://www.cbssports.com/nfl/stats/leaders/live/K/20/
# <Response [200]>
# ('K', 20) (8, 6)
# https://www.cbssports.com/nfl/stats/leaders/live/K/21/
# <Response [200]>
# ('K', 21) (3, 6)
# https://www.cbssports.com/nfl/stats/leaders/live/K/23/
# <Response [200]>
# ('K', 23) (2, 6)

# %%
file_list
# Out:
# ['./nfl_data/weekly/cbs_weekly/week-19_QB.xls',
#  './nfl_data/weekly/cbs_weekly/week-20_QB.xls',
#  './nfl_data/weekly/cbs_weekly/week-21_QB.xls',
#  './nfl_data/weekly/cbs_weekly/week-23_QB.xls',
#  './nfl_data/weekly/cbs_weekly/week-19_WR.xls',
#  './nfl_data/weekly/cbs_weekly/week-20_WR.xls',
#  './nfl_data/weekly/cbs_weekly/week-21_WR.xls',
#  './nfl_data/weekly/cbs_weekly/week-23_WR.xls',
#  './nfl_data/weekly/cbs_weekly/week-19_RB.xls',
#  './nfl_data/weekly/cbs_weekly/week-20_RB.xls',
#  './nfl_data/weekly/cbs_weekly/week-21_RB.xls',
#  './nfl_data/weekly/cbs_weekly/week-23_RB.xls',
#  './nfl_data/weekly/cbs_weekly/week-19_TE.xls',
#  './nfl_data/weekly/cbs_weekly/week-20_TE.xls',
#  './nfl_data/weekly/cbs_weekly/week-21_TE.xls',
#  './nfl_data/weekly/cbs_weekly/week-23_TE.xls',
#  './nfl_data/weekly/cbs_weekly/week-19_K.xls',
#  './nfl_data/weekly/cbs_weekly/week-20_K.xls',
#  './nfl_data/weekly/cbs_weekly/week-21_K.xls',
#  './nfl_data/weekly/cbs_weekly/week-23_K.xls']

# %%
# get df started with the 1st file './nfl_data/week-19_QB.xls'.  This way we have something to merge to.

if 'QB' in file_list[0]:
    df_qb = pd.read_html('./nfl_data/weekly/cbs_weekly/week-19_QB.xls')
    df_qb = pd.DataFrame(df_qb[0])
    df_qb = df_qb.droplevel(0, axis=1)
    df_qb['Week'] = re.search(r'(?<=\-)\s*(..)', file_list[0])[0]
    df_qb['Pos'] = [i.split()[-1] for i in df_qb['Player  Player on team']]
    df_qb.rename(columns={'Player  Player on team': 'Player'}, inplace=True)
    df_qb['Player'] = df_qb['Player'].map(lambda x: x.split()[3] + ' ' + x.split()[4])
    df_qb

# %%
df_qb.shape
# Out:
# (13, 13)

# %%
for file in file_list[1:]:
    if 'QB' in file:
        print(file)
        data = pd.read_html(file)
        df = data[0]
        df = df.droplevel(0, axis=1)
        df['Week'] = re.search(r'(?<=\-)\s*(..)', file)[0]
        df['Pos'] = [i.split()[-1] for i in df['Player  Player on team']]
        df.rename(columns={'Player  Player on team': 'Player'}, inplace=True)
        df['Player'] = df['Player'].map(lambda x: x.split()[3] + ' ' + x.split()[4])
        dfs = [df_qb, df]
        df_qb = pd.concat([df_qb.squeeze() for df_qb in dfs], ignore_index=True)

print(f'The shape of the updated df is {df_qb.shape}')
# Out:
# ./nfl_data/weekly/cbs_weekly/week-20_QB.xls
# ./nfl_data/weekly/cbs_weekly/week-21_QB.xls
# ./nfl_data/weekly/cbs_weekly/week-23_QB.xls
# The shape of the updated df is (26, 13)

# %%
df_qb.sort_values(by=['Player', 'Week'])
# Out:
#                 Player             Game FPTS  Fantasy Points  \
# 18       Aaron Rodgers    SF 13 - GB 10                    9
# 6   Ben Roethlisberger   KC 42 - PIT 21                   20
# 3         Dak Prescott   SF 23 - DAL 17                   22
# 9           Derek Carr   CIN 26 - LV 19                   16
# 8          Jalen Hurts   TB 31 - PHI 15                   17
# 10     Jimmy Garoppolo   SF 23 - DAL 17                    4
# 20     Jimmy Garoppolo    SF 13 - GB 10                    3
# 23     Jimmy Garoppolo   LAR 20 - SF 17                   19
# 5           Joe Burrow   CIN 26 - LV 19                   21
# 17          Joe Burrow  CIN 19 - TEN 16                   11
# 21          Joe Burrow   CIN 27 - KC 24                   24
# 25          Joe Burrow  LAR 23 - CIN 20                   16
# 0           Josh Allen   BUF 47 - NE 17                   48
# 13          Josh Allen   KC 42 - BUF 36                   45
# 11        Kyler Murray  LAR 34 - ARI 11                    3
# 7            Mac Jones   BUF 47 - NE 17                   18
# 2     Matthew Stafford  LAR 34 - ARI 11                   28
# 15    Matthew Stafford   LAR 30 - TB 27                   32
# 22    Matthew Stafford   LAR 20 - SF 17                   23
# 24    Matthew Stafford  LAR 23 - CIN 20                   25
# 12   Mitchell Trubisky   BUF 47 - NE 17                    —
# 1      Patrick Mahomes   KC 42 - PIT 21                   46
# 14     Patrick Mahomes   KC 42 - BUF 36                   45
# 19      Ryan Tannehill  CIN 19 - TEN 16                    9
# 4            Tom Brady   TB 31 - PHI 15                   22
# 16           Tom Brady   LAR 30 - TB 27                   15
#
#    CMP  Pass Completions ATT  Pass Attempts YDS  Passing Yards  \
# 18                    20                 29                225
# 6                     29                 44                215
# 3                     23                 43                254
# 9                     29                 54                310
# 8                     23                 43                258
# 10                    16                 25                172
# 20                    11                 19                131
# 23                    16                 30                232
# 5                     24                 34                244
# 17                    28                 37                348
# 21                    23                 38                250
# 25                    22                 33                263
# 0                     21                 25                308
# 13                    27                 37                329
# 11                    19                 34                137
# 7                     24                 38                232
# 2                     13                 17                202
# 15                    28                 38                366
# 22                    31                 45                337
# 24                    26                 40                283
# 12                     —                  —                  —
# 1                     30                 39                404
# 14                    33                 44                378
# 19                    15                 24                220
# 4                     29                 37                271
# 16                    30                 54                329
#
#    TD  Touchdown Passes INT  Interceptions Thrown ATT  Rushing Attempts  \
# 18                    0                         0                     —
# 6                     2                         0                     2
# 3                     1                         1                     4
# 9                     1                         1                     1
# 8                     1                         2                     8
# 10                    0                         1                     1
# 20                    0                         1                     —
# 23                    2                         1                     1
# 5                     2                         0                     2
# 17                    0                         1                     2
# 21                    2                         1                     5
# 25                    1                         0                     2
# 0                     5                         0                     6
# 13                    4                         0                    11
# 11                    0                         2                     2
# 7                     2                         2                     2
# 2                     2                         0                     6
# 15                    2                         0                     4
# 22                    2                         1                     5
# 24                    3                         2                     3
# 12                    —                         —                     3
# 1                     5                         1                     3
# 14                    3                         0                     7
# 19                    1                         3                     3
# 4                     2                         0                     —
# 16                    1                         1                     1
#
#    YDS  Rushing Yards TD  Rushing Touchdowns Week Pos
# 18                  —                      —   20  QB
# 6                  -1                      0   19  QB
# 3                  27                      1   19  QB
# 9                  20                      0   19  QB
# 8                  39                      0   19  QB
# 10                  1                      0   19  QB
# 20                  —                      —   20  QB
# 23                  4                      0   21  QB
# 5                  -2                      0   19  QB
# 17                  5                      0   20  QB
# 21                 25                      0   21  QB
# 25                  3                      0   23  QB
# 0                  66                      0   19  QB
# 13                 68                      0   20  QB
# 11                  6                      0   19  QB
# 7                  18                      0   19  QB
# 2                  22                      1   19  QB
# 15                  6                      1   20  QB
# 22                  8                      0   21  QB
# 24                  6                      0   23  QB
# 12                 -2                      0   19  QB
# 1                  29                      0   19  QB
# 14                 69                      1   20  QB
# 19                 12                      0   20  QB
# 4                   —                      —   19  QB
# 16                  0                      0   20  QB

# %%
df_qb = df_qb.replace('—', 0) # get rid of the dashes, impute with 0
df_qb.head()
# Out:
#              Player             Game FPTS  Fantasy Points  \
# 0        Josh Allen   BUF 47 - NE 17                   48
# 1   Patrick Mahomes   KC 42 - PIT 21                   46
# 2  Matthew Stafford  LAR 34 - ARI 11                   28
# 3      Dak Prescott   SF 23 - DAL 17                   22
# 4         Tom Brady   TB 31 - PHI 15                   22
#
#   CMP  Pass Completions ATT  Pass Attempts YDS  Passing Yards  \
# 0                    21                 25                308
# 1                    30                 39                404
# 2                    13                 17                202
# 3                    23                 43                254
# 4                    29                 37                271
#
#   TD  Touchdown Passes INT  Interceptions Thrown ATT  Rushing Attempts  \
# 0                    5                         0                     6
# 1                    5                         1                     3
# 2                    2                         0                     6
# 3                    1                         1                     4
# 4                    2                         0                     0
#
#   YDS  Rushing Yards TD  Rushing Touchdowns Week Pos
# 0                 66                      0   19  QB
# 1                 29                      0   19  QB
# 2                 22                      1   19  QB
# 3                 27                      1   19  QB
# 4                  0                      0   19  QB

# %%
# Attempt to convert all columns to int, those that fail are stored in list
numcols_to_change = df_qb.columns
numcols_to_change2 = []
for col in numcols_to_change:
    try:
        df_qb[col] = df_qb[col].astype(int)
        print('success!')
    except:
        numcols_to_change2.append(col)
        print(f'need to clean column: {col}')
# Out:
# need to clean column: Player
# need to clean column: Game
# success!
# success!
# success!
# success!
# success!
# success!
# success!
# success!
# success!
# success!
# need to clean column: Pos

# %%
max_week = df_qb['Week'].max()

df_qb.to_csv(f'./nfl_data/weekly/cbs_weekly/passing_through_week-{max_week}.csv', index=0)

# %%
df_qb.head()
# Out:
#              Player             Game  FPTS  Fantasy Points  \
# 0        Josh Allen   BUF 47 - NE 17                    48
# 1   Patrick Mahomes   KC 42 - PIT 21                    46
# 2  Matthew Stafford  LAR 34 - ARI 11                    28
# 3      Dak Prescott   SF 23 - DAL 17                    22
# 4         Tom Brady   TB 31 - PHI 15                    22
#
#    CMP  Pass Completions  ATT  Pass Attempts  YDS  Passing Yards  \
# 0                     21                  25                 308
# 1                     30                  39                 404
# 2                     13                  17                 202
# 3                     23                  43                 254
# 4                     29                  37                 271
#
#    TD  Touchdown Passes  INT  Interceptions Thrown  ATT  Rushing Attempts  \
# 0                     5                          0                      6
# 1                     5                          1                      3
# 2                     2                          0                      6
# 3                     1                          1                      4
# 4                     2                          0                      0
#
#    YDS  Rushing Yards  TD  Rushing Touchdowns  Week Pos
# 0                  66                       0    19  QB
# 1                  29                       0    19  QB
# 2                  22                       1    19  QB
# 3                  27                       1    19  QB
# 4                   0                       0    19  QB

# %%
df_qb['Home_Team'] = df_qb['Game'].map(lambda score: score.split()[0])
df_qb['Away_Team'] = df_qb['Game'].map(lambda score: score.split()[3])

# %%
Team_Abbreviations_Dict = {
    'Arizona Cardinals': 'ARI',
    'Atlanta Falcons': 'ATL',
    'Baltimore Ravens': 'BAL',
    'Buffalo Bills' : 'BUF',
    'Carolina Panthers': 'CAR',
    'Chicago Bears': 'CHI',
    'Cincinnati Bengals': 'CIN',
    'Cleveland Browns': 'CLE',
    'Dallas Cowboys': 'DAL',
    'Denver Broncos': 'DEN',
    'Detroit Lions': 'DET',
    'Green Bay Packers': 'GB',
    'Houston Texans': 'HOU',
    'Indianapolis Colts': 'IND',
    'Jacksonville Jaguars': 'JAX',
    'Kansas City Chiefs': 'KC',
    'Miami Dolphins': 'MIA',
    'Minnesota Vikings': 'MIN',
    'New England Patriots': 'NE',
    'New Orleans Saints': 'NO',
    'NY Giants': 'NYG',
    'NY Jets': 'NYJ',
    'Las Vegas Raiders': 'LV',
    'Philadelphia Eagles': 'PHI',
    'Pittsburgh Steelers': 'PIT',
    'Los Angeles Chargers': 'LAC',
    'San Francisco 49ers': 'SF',
    'Seattle Seahawks': 'SEA',
    'Los Angeles Rams': 'LAR',
    'Tampa Bay Buccaneers': 'TB',
    'Tennessee Titans': 'TEN',
    'Washington Commanders': 'WAS'
}

# %%
df_qb.head()
# Out:
#              Player             Game  FPTS  Fantasy Points  \
# 0        Josh Allen   BUF 47 - NE 17                    48
# 1   Patrick Mahomes   KC 42 - PIT 21                    46
# 2  Matthew Stafford  LAR 34 - ARI 11                    28
# 3      Dak Prescott   SF 23 - DAL 17                    22
# 4         Tom Brady   TB 31 - PHI 15                    22
#
#    CMP  Pass Completions  ATT  Pass Attempts  YDS  Passing Yards  \
# 0                     21                  25                 308
# 1                     30                  39                 404
# 2                     13                  17                 202
# 3                     23                  43                 254
# 4                     29                  37                 271
#
#    TD  Touchdown Passes  INT  Interceptions Thrown  ATT  Rushing Attempts  \
# 0                     5                          0                      6
# 1                     5                          1                      3
# 2                     2                          0                      6
# 3                     1                          1                      4
# 4                     2                          0                      0
#
#    YDS  Rushing Yards  TD  Rushing Touchdowns  Week Pos Home_Team Away_Team
# 0                  66                       0    19  QB       BUF        NE
# 1                  29                       0    19  QB        KC       PIT
# 2                  22                       1    19  QB       LAR       ARI
# 3                  27                       1    19  QB        SF       DAL
# 4                   0                       0    19  QB        TB       PHI

# %%
def get_key(val):
    for key, value in Team_Abbreviations_Dict.items():
         if val == value:
            return key
 
    return "key doesn't exist"

# %%
df_qb['Home_Team_Name_Full'] = df_qb['Home_Team'].map(get_key)
df_qb['Away_Team_Name_Full'] = df_qb['Away_Team'].map(get_key)
df_qb['Home_Team_Name_Mascot'] = df_qb['Home_Team_Name_Full'].map(lambda x: x.split()[-1])
df_qb['Away_Team_Name_Mascot'] = df_qb['Away_Team_Name_Full'].map(lambda x: x.split()[-1])

# %%
df_qb
# Out:
#                 Player             Game  FPTS  Fantasy Points  \
# 0           Josh Allen   BUF 47 - NE 17                    48
# 1      Patrick Mahomes   KC 42 - PIT 21                    46
# 2     Matthew Stafford  LAR 34 - ARI 11                    28
# 3         Dak Prescott   SF 23 - DAL 17                    22
# 4            Tom Brady   TB 31 - PHI 15                    22
# 5           Joe Burrow   CIN 26 - LV 19                    21
# 6   Ben Roethlisberger   KC 42 - PIT 21                    20
# 7            Mac Jones   BUF 47 - NE 17                    18
# 8          Jalen Hurts   TB 31 - PHI 15                    17
# 9           Derek Carr   CIN 26 - LV 19                    16
# 10     Jimmy Garoppolo   SF 23 - DAL 17                     4
# 11        Kyler Murray  LAR 34 - ARI 11                     3
# 12   Mitchell Trubisky   BUF 47 - NE 17                     0
# 13          Josh Allen   KC 42 - BUF 36                    45
# 14     Patrick Mahomes   KC 42 - BUF 36                    45
# 15    Matthew Stafford   LAR 30 - TB 27                    32
# 16           Tom Brady   LAR 30 - TB 27                    15
# 17          Joe Burrow  CIN 19 - TEN 16                    11
# 18       Aaron Rodgers    SF 13 - GB 10                     9
# 19      Ryan Tannehill  CIN 19 - TEN 16                     9
# 20     Jimmy Garoppolo    SF 13 - GB 10                     3
# 21          Joe Burrow   CIN 27 - KC 24                    24
# 22    Matthew Stafford   LAR 20 - SF 17                    23
# 23     Jimmy Garoppolo   LAR 20 - SF 17                    19
# 24    Matthew Stafford  LAR 23 - CIN 20                    25
# 25          Joe Burrow  LAR 23 - CIN 20                    16
#
#     CMP  Pass Completions  ATT  Pass Attempts  YDS  Passing Yards  \
# 0                      21                  25                 308
# 1                      30                  39                 404
# 2                      13                  17                 202
# 3                      23                  43                 254
# 4                      29                  37                 271
# 5                      24                  34                 244
# 6                      29                  44                 215
# 7                      24                  38                 232
# 8                      23                  43                 258
# 9                      29                  54                 310
# 10                     16                  25                 172
# 11                     19                  34                 137
# 12                      0                   0                   0
# 13                     27                  37                 329
# 14                     33                  44                 378
# 15                     28                  38                 366
# 16                     30                  54                 329
# 17                     28                  37                 348
# 18                     20                  29                 225
# 19                     15                  24                 220
# 20                     11                  19                 131
# 21                     23                  38                 250
# 22                     31                  45                 337
# 23                     16                  30                 232
# 24                     26                  40                 283
# 25                     22                  33                 263
#
#     TD  Touchdown Passes  INT  Interceptions Thrown  ATT  Rushing Attempts  \
# 0                      5                          0                      6
# 1                      5                          1                      3
# 2                      2                          0                      6
# 3                      1                          1                      4
# 4                      2                          0                      0
# 5                      2                          0                      2
# 6                      2                          0                      2
# 7                      2                          2                      2
# 8                      1                          2                      8
# 9                      1                          1                      1
# 10                     0                          1                      1
# 11                     0                          2                      2
# 12                     0                          0                      3
# 13                     4                          0                     11
# 14                     3                          0                      7
# 15                     2                          0                      4
# 16                     1                          1                      1
# 17                     0                          1                      2
# 18                     0                          0                      0
# 19                     1                          3                      3
# 20                     0                          1                      0
# 21                     2                          1                      5
# 22                     2                          1                      5
# 23                     2                          1                      1
# 24                     3                          2                      3
# 25                     1                          0                      2
#
#     YDS  Rushing Yards  TD  Rushing Touchdowns  Week Pos Home_Team Away_Team  \
# 0                   66                       0    19  QB       BUF        NE
# 1                   29                       0    19  QB        KC       PIT
# 2                   22                       1    19  QB       LAR       ARI
# 3                   27                       1    19  QB        SF       DAL
# 4                    0                       0    19  QB        TB       PHI
# 5                   -2                       0    19  QB       CIN        LV
# 6                   -1                       0    19  QB        KC       PIT
# 7                   18                       0    19  QB       BUF        NE
# 8                   39                       0    19  QB        TB       PHI
# 9                   20                       0    19  QB       CIN        LV
# 10                   1                       0    19  QB        SF       DAL
# 11                   6                       0    19  QB       LAR       ARI
# 12                  -2                       0    19  QB       BUF        NE
# 13                  68                       0    20  QB        KC       BUF
# 14                  69                       1    20  QB        KC       BUF
# 15                   6                       1    20  QB       LAR        TB
# 16                   0                       0    20  QB       LAR        TB
# 17                   5                       0    20  QB       CIN       TEN
# 18                   0                       0    20  QB        SF        GB
# 19                  12                       0    20  QB       CIN       TEN
# 20                   0                       0    20  QB        SF        GB
# 21                  25                       0    21  QB       CIN        KC
# 22                   8                       0    21  QB       LAR        SF
# 23                   4                       0    21  QB       LAR        SF
# 24                   6                       0    23  QB       LAR       CIN
# 25                   3                       0    23  QB       LAR       CIN
#
#      Home_Team_Name_Full   Away_Team_Name_Full Home_Team_Name_Mascot  \
# 0          Buffalo Bills  New England Patriots                 Bills
# 1     Kansas City Chiefs   Pittsburgh Steelers                Chiefs
# 2       Los Angeles Rams     Arizona Cardinals                  Rams
# 3    San Francisco 49ers        Dallas Cowboys                 49ers
# 4   Tampa Bay Buccaneers   Philadelphia Eagles            Buccaneers
# 5     Cincinnati Bengals     Las Vegas Raiders               Bengals
# 6     Kansas City Chiefs   Pittsburgh Steelers                Chiefs
# 7          Buffalo Bills  New England Patriots                 Bills
# 8   Tampa Bay Buccaneers   Philadelphia Eagles            Buccaneers
# 9     Cincinnati Bengals     Las Vegas Raiders               Bengals
# 10   San Francisco 49ers        Dallas Cowboys                 49ers
# 11      Los Angeles Rams     Arizona Cardinals                  Rams
# 12         Buffalo Bills  New England Patriots                 Bills
# 13    Kansas City Chiefs         Buffalo Bills                Chiefs
# 14    Kansas City Chiefs         Buffalo Bills                Chiefs
# 15      Los Angeles Rams  Tampa Bay Buccaneers                  Rams
# 16      Los Angeles Rams  Tampa Bay Buccaneers                  Rams
# 17    Cincinnati Bengals      Tennessee Titans               Bengals
# 18   San Francisco 49ers     Green Bay Packers                 49ers
# 19    Cincinnati Bengals      Tennessee Titans               Bengals
# 20   San Francisco 49ers     Green Bay Packers                 49ers
# 21    Cincinnati Bengals    Kansas City Chiefs               Bengals
# 22      Los Angeles Rams   San Francisco 49ers                  Rams
# 23      Los Angeles Rams   San Francisco 49ers                  Rams
# 24      Los Angeles Rams    Cincinnati Bengals                  Rams
# 25      Los Angeles Rams    Cincinnati Bengals                  Rams
#
#    Away_Team_Name_Mascot
# 0               Patriots
# 1               Steelers
# 2              Cardinals
# 3                Cowboys
# 4                 Eagles
# 5                Raiders
# 6               Steelers
# 7               Patriots
# 8                 Eagles
# 9                Raiders
# 10               Cowboys
# 11             Cardinals
# 12              Patriots
# 13                 Bills
# 14                 Bills
# 15            Buccaneers
# 16            Buccaneers
# 17                Titans
# 18               Packers
# 19                Titans
# 20               Packers
# 21                Chiefs
# 22                 49ers
# 23                 49ers
# 24               Bengals
# 25               Bengals

# %%
# df_qb.at[4,'Week']=19 # Change a week to ensure the join is working properly

# %%
weather_df = pd.read_csv('./nfl_data/weekly/weather/all_weeks_weather.csv')
weather_df.head()
# Out:
#        Away        Home                     Forecast  \
# 0   Cowboys  Buccaneers  80f Humid and Partly Cloudy
# 1    Eagles     Falcons                         DOME
# 2  Steelers       Bills            72f Mostly Cloudy
# 3   Vikings     Bengals                    82f Clear
# 4     49ers       Lions                         DOME
#
#                                   Extended Forecast     Wind  Week  \
# 0      Humid and Partly Cloudy. Rain until evening.   6m WSW     1
# 1                  Clear. Clear throughout the day.        0     1
# 2                    Mostly Cloudy. Rain overnight.  12m WSW     1
# 3                  Clear. Clear throughout the day.   11m SW     1
# 4  Mostly Cloudy. Mostly cloudy throughout the day.        0     1
#
#    Wind_Speed_MPH Wind_Direction  Temp             Weather_Desc
# 0               6            WSW    80  Humid and Partly Cloudy
# 1               0              0     0                        0
# 2              12            WSW    72            Mostly Cloudy
# 3              11             SW    82                    Clear
# 4               0              0     0                        0

# %%
df = pd.merge(df_qb, weather_df, left_on = ['Home_Team_Name_Mascot', 'Week'], right_on = ['Home', 'Week'], how = 'inner')
df
# Out:
# Empty DataFrame
# Columns: [Player, Game, FPTS  Fantasy Points, CMP  Pass Completions, ATT  Pass Attempts, YDS  Passing Yards, TD  Touchdown Passes, INT  Interceptions Thrown, ATT  Rushing Attempts, YDS  Rushing Yards, TD  Rushing Touchdowns, Week, Pos, Home_Team, Away_Team, Home_Team_Name_Full, Away_Team_Name_Full, Home_Team_Name_Mascot, Away_Team_Name_Mascot, Away, Home, Forecast, Extended Forecast, Wind, Wind_Speed_MPH, Wind_Direction, Temp, Weather_Desc]
# Index: []
#
# [0 rows x 28 columns]
