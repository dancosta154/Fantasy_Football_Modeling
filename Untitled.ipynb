# %%
import pandas as pd
import numpy as np
import requests
import os
import re

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics

from sklearn.model_selection import cross_val_score

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# all_positions = ['QB', 'WR', 'RB', 'TE', 'K']
# weeks = [week for week in range(starting_week, current_week + 1)]

# file_list = []

# for position in all_positions:
    # for week in weeks:
url = 'https://fantasydata.com/nfl/fantasy-football-leaders?season=2021&seasontype=1&scope=2&subscope=1&startweek=1&endweek=1&aggregatescope=1&range=3'
res = requests.get(url)
output = open('./nfl_data/test.xls', 'wb')
output.write(res.content)
output.close()
data = pd.read_html(f'./nfl_data/test.xls')
data[3]
# Out:
#                                    0
# 0        Chandler Jones Fantasy  ARI
# 1          Kyler Murray Fantasy  ARI
# 2        Patrick Mahomes Fantasy  KC
# 3         Jameis Winston Fantasy  NO
# 4            Jared Goff Fantasy  DET
# 5           Jalen Hurts Fantasy  PHI
# 6          Dak Prescott Fantasy  DAL
# 7              Tom Brady Fantasy  TB
# 8        Russell Wilson Fantasy  SEA
# 9            Tyreek Hill Fantasy  KC
# 10         Amari Cooper Fantasy  DAL
# 11     Matthew Stafford Fantasy  LAR
# 12            Derek Carr Fantasy  LV
# 13         Tyrod Taylor Fantasy  HOU
# 14          Deebo Samuel Fantasy  SF
# 15         Kirk Cousins Fantasy  MIN
# 16        Tyler Lockett Fantasy  SEA
# 17          Corey Davis Fantasy  NYJ
# 18         Daniel Jones Fantasy  NYG
# 19         Adam Thielen Fantasy  MIN
# 20            Joe Mixon Fantasy  CIN
# 21        Rob Gronkowski Fantasy  TB
# 22    Teddy Bridgewater Fantasy  DEN
# 23      DeAndre Hopkins Fantasy  ARI
# ...
